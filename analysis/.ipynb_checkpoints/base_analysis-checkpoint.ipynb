# %% [markdown]
# # Base Analysis of RTR Data

# %% [markdown]
# ## Load Data from MongoDB

# %%
import pandas as pd 
import pymongo 
import yaml
import re

# %%
# Load data from MongoDB
# Import cred from yaml
with open("/Users/samivanecky/git/running-shoe-app/mongo_creds.yaml") as f:
    creds = yaml.safe_load(f)

# Connect to mongo
connection_str = "mongodb+srv://trackrabbit:" + str(creds['pwd']) + "@running-shoes.ncb9yfc.mongodb.net/?retryWrites=true&w=majority"
# Connect to MongoDB
client = pymongo.MongoClient(connection_str)
# Connvect to database
db = client["running-shoes"]
# Connect to collection
collection = db["roadtrailrun"]

# %%
# Load txt file of stop words
with open("/Users/samivanecky/git/running-shoe-app/resources/stop_words_expanded.txt") as f:
    stop_words = f.read()
# Remove new lines & convert to list
stop_words = re.sub('\n', ' ', stop_words).split()

# %%
docs = collection.find()
df = pd.DataFrame(list(docs))

# %%
temp = df[df['name'].str.contains('Hoka Tecton')]

# %%
txt = temp['review_txt'].iloc[0]

# %% [markdown]
# ## Sample Text Analysis

# %%
from nltk.util import ngrams, bigrams, trigrams
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string
from collections import Counter

# %%
# Get punctuation
punct = list(string.punctuation)

# %%
toks = word_tokenize(txt)

# %%
# Filter out stop words & punctuation
toks = [word.lower() for word in toks]
toks = [word for word in toks if word not in stop_words]
toks = [word for word in toks if word not in punct]
toks = [re.sub(r'[^\w\s]', ' ', word) for word in toks]
toks = [word for word in toks if word is not ' ']
toks = [word.translate(str.maketrans("", "", string.punctuation)) for word in toks]
# toks = [re.sub(r'\s+', ' ', word) for word in toks]

# %%
string_counts = Counter(list(ngrams(toks, 5)))

# %%
string_counts.most_common()
# Out:
# [(('men', ' s', 'women', ' s', 'shop'), 6),
#  (('code', 'rtr5all', '5', 'products', 'sale'), 3),
#  (('rtr5all', '5', 'products', 'sale', 'products'), 3),
#  (('hoka', 'tecton', 'multi', 'tester', 'review'), 2),
#  (('tecton', 'multi', 'tester', 'review', 'light'), 2),
#  (('multi', 'tester', 'review', 'light', 'fast'), 2),
#  ((' s', 'women', ' s', 'shop', 'herefree'), 2),
#  (('tecton', 'men', ' s', 'women', ' s'), 2),
#  (('latest', 'run', 'gear', 'great', 'clearance'), 2),
#  (('run', 'gear', 'great', 'clearance', 'deals'), 2),
#  (('gear', 'great', 'clearance', 'deals', 'shop'), 2),
#  (('great', 'clearance', 'deals', 'shop', 'europe'), 2),
#  (('clearance', 'deals', 'shop', 'europe', 'shop'), 2),
#  (('deals', 'shop', 'europe', 'shop', 'eu'), 2),
#  (('shop', 'europe', 'shop', 'eu', 'code'), 2),
#  (('europe', 'shop', 'eu', 'code', 'rtr5all'), 2),
#  (('shop', 'eu', 'code', 'rtr5all', '5'), 2),
#  (('eu', 'code', 'rtr5all', '5', 'products'), 2),
#  (('5', 'products', 'sale', 'products', 'australia'), 2),
#  (('products', 'sale', 'products', 'australia', 'shop'), 2),
#  (('sale', 'products', 'australia', 'shop', 'european'), 2),
#  (('products', 'australia', 'shop', 'european', 'readers'), 2),
#  (('australia', 'shop', 'european', 'readers', 'save'), 2),
#  (('shop', 'european', 'readers', 'save', 'top4running'), 2),
#  (('european', 'readers', 'save', 'top4running', 'code'), 2),
#  (('readers', 'save', 'top4running', 'code', 'rtrtop4'), 2),
#  (('save', 'top4running', 'code', 'rtrtop4', '5'), 2),
#  (('top4running', 'code', 'rtrtop4', '5', 'products'), 2),
#  (('code', 'rtrtop4', '5', 'products', 'sales'), 2),
#  ((' ', 'puma', 'running', 'velocity', 'nitro'), 2),
#  (('puma', 'running', 'velocity', 'nitro', '2'), 2),
#  (('august', '15', 'july', '14', 'june'), 2),
#  (('march', '2', 'february', '5', 'january'), 2),
#  (('april', '6', 'march', '1', 'february'), 2),
#  (('april', '1', 'march', '2', 'february'), 2),
#  (('pages', 'home', 'reviews', 'road', 'trail'), 1),
#  (('home', 'reviews', 'road', 'trail', 'run'), 1),
#  (('reviews', 'road', 'trail', 'run', 'shoes'), 1),
#  (('road', 'trail', 'run', 'shoes', 'gear'), 1),
#  (('trail', 'run', 'shoes', 'gear', 'tech'), 1),
#  (('run', 'shoes', 'gear', 'tech', 'brand'), 1),
#  (('shoes', 'gear', 'tech', 'brand', 'latest'), 1),
#  (('gear', 'tech', 'brand', 'latest', 'run'), 1),
#  (('tech', 'brand', 'latest', 'run', 'shoe'), 1),
#  (('brand', 'latest', 'run', 'shoe', 'gear'), 1),
#  (('latest', 'run', 'shoe', 'gear', 'reviews'), 1),
#  (('run', 'shoe', 'gear', 'reviews', 'articles'), 1),
#  (('shoe', 'gear', 'reviews', 'articles', '2022'), 1),
#  (('gear', 'reviews', 'articles', '2022', 'top'), 1),
#  (('reviews', 'articles', '2022', 'top', 'running'), 1),
#  (('articles', '2022', 'top', 'running', 'shoes'), 1),
#  (('2022', 'top', 'running', 'shoes', 'gear'), 1),
#  (('top', 'running', 'shoes', 'gear', 'awards'), 1),
#  (('running', 'shoes', 'gear', 'awards', '2023'), 1),
#  (('shoes', 'gear', 'awards', '2023', 'running'), 1),
#  (('gear', 'awards', '2023', 'running', 'shoe'), 1),
#  (('awards', '2023', 'running', 'shoe', 'previews'), 1),
#  (('2023', 'running', 'shoe', 'previews', 'quick'), 1),
#  (('running', 'shoe', 'previews', 'quick', 'strides'), 1),
#  (('shoe', 'previews', 'quick', 'strides', 'rtr'), 1),
#  (('previews', 'quick', 'strides', 'rtr', 'team'), 1),
#  (('quick', 'strides', 'rtr', 'team', 'testing'), 1),
#  (('strides', 'rtr', 'team', 'testing', 'notes'), 1),
#  (('rtr', 'team', 'testing', 'notes', 'reviewer'), 1),
#  (('team', 'testing', 'notes', 'reviewer', 'bios'), 1),
#  (('testing', 'notes', 'reviewer', 'bios', 'rtr'), 1),
#  (('notes', 'reviewer', 'bios', 'rtr', 'german'), 1),
#  (('reviewer', 'bios', 'rtr', 'german', 'spanish'), 1),
#  (('bios', 'rtr', 'german', 'spanish', 'french'), 1),
#  (('rtr', 'german', 'spanish', 'french', 'portuguese'), 1),
#  (('german', 'spanish', 'french', 'portuguese', 'polish'), 1),
#  (('spanish', 'french', 'portuguese', 'polish', 'reviews'), 1),
#  (('french', 'portuguese', 'polish', 'reviews', 'roadtrailride'), 1),
#  (('portuguese', 'polish', 'reviews', 'roadtrailride', 'bike'), 1),
#  (('polish', 'reviews', 'roadtrailride', 'bike', 'bike'), 1),
#  (('reviews', 'roadtrailride', 'bike', 'bike', 'gear'), 1),
#  (('roadtrailride', 'bike', 'bike', 'gear', 'reviews'), 1),
#  (('bike', 'bike', 'gear', 'reviews', 'race'), 1),
#  (('bike', 'gear', 'reviews', 'race', 'reports'), 1),
#  (('gear', 'reviews', 'race', 'reports', 'racer'), 1),
#  (('reviews', 'race', 'reports', 'racer', 'stories'), 1),
#  (('race', 'reports', 'racer', 'stories', 'thursday'), 1),
#  (('reports', 'racer', 'stories', 'thursday', 'february'), 1),
#  (('racer', 'stories', 'thursday', 'february', '03'), 1),
#  (('stories', 'thursday', 'february', '03', '2022'), 1),
#  (('thursday', 'february', '03', '2022', 'hoka'), 1),
#  (('february', '03', '2022', 'hoka', 'tecton'), 1),
#  (('03', '2022', 'hoka', 'tecton', 'multi'), 1),
#  (('2022', 'hoka', 'tecton', 'multi', 'tester'), 1),
#  (('tester', 'review', 'light', 'fast', 'flexible'), 1),
#  (('review', 'light', 'fast', 'flexible', 'carbon'), 1),
#  (('light', 'fast', 'flexible', 'carbon', 'super'), 1),
#  (('fast', 'flexible', 'carbon', 'super', 'critical'), 1),
#  (('flexible', 'carbon', 'super', 'critical', 'foam'), 1),
#  (('carbon', 'super', 'critical', 'foam', 'energetic'), 1),
#  (('super', 'critical', 'foam', 'energetic', 'trail'), 1),
#  (('critical', 'foam', 'energetic', 'trail', 'racer'), 1),
#  (('foam', 'energetic', 'trail', 'racer', '13'), 1),
#  (('energetic', 'trail', 'racer', '13', 'comparisons'), 1),
#  (('trail', 'racer', '13', 'comparisons', 'article'), 1),
#  (('racer', '13', 'comparisons', 'article', 'sam'), 1),
#  (('13', 'comparisons', 'article', 'sam', 'winebaum'), 1),
#  (('comparisons', 'article', 'sam', 'winebaum', 'mike'), 1),
#  (('article', 'sam', 'winebaum', 'mike', 'postaski'), 1),
#  (('sam', 'winebaum', 'mike', 'postaski', 'jeff'), 1),
#  (('winebaum', 'mike', 'postaski', 'jeff', 'vallierehoka'), 1),
#  (('mike', 'postaski', 'jeff', 'vallierehoka', 'tecton'), 1),
#  (('postaski', 'jeff', 'vallierehoka', 'tecton', '200'), 1),
#  (('jeff', 'vallierehoka', 'tecton', '200', 'introductionsam'), 1),
#  (('vallierehoka', 'tecton', '200', 'introductionsam', 'tecton'), 1),
#  (('tecton', '200', 'introductionsam', 'tecton', 'carbon'), 1),
#  (('200', 'introductionsam', 'tecton', 'carbon', 'plated'), 1),
#  (('introductionsam', 'tecton', 'carbon', 'plated', 'max'), 1),
#  (('tecton', 'carbon', 'plated', 'max', 'cushion'), 1),
#  (('carbon', 'plated', 'max', 'cushion', 'trail'), 1),
#  (('plated', 'max', 'cushion', 'trail', 'racing'), 1),
#  (('max', 'cushion', 'trail', 'racing', 'training'), 1),
#  (('cushion', 'trail', 'racing', 'training', 'shoe'), 1),
#  (('trail', 'racing', 'training', 'shoe', 'standpoint'), 1),
#  (('racing', 'training', 'shoe', 'standpoint', 'significantly'), 1),
#  (('training', 'shoe', 'standpoint', 'significantly', 'important'), 1),
#  (('shoe', 'standpoint', 'significantly', 'important', 'hoka'), 1),
#  (('standpoint', 'significantly', 'important', 'hoka', 'trail'), 1),
#  (('significantly', 'important', 'hoka', 'trail', 'road'), 1),
#  (('important', 'hoka', 'trail', 'road', 'shoe'), 1),
#  (('hoka', 'trail', 'road', 'shoe', 'introduction'), 1),
#  (('trail', 'road', 'shoe', 'introduction', 'original'), 1),
#  (('road', 'shoe', 'introduction', 'original', 'speedgoat'), 1),
#  (('shoe', 'introduction', 'original', 'speedgoat', 'evo'), 1),
#  (('introduction', 'original', 'speedgoat', 'evo', 'speedgoat'), 1),
#  (('original', 'speedgoat', 'evo', 'speedgoat', 'key'), 1),
#  (('speedgoat', 'evo', 'speedgoat', 'key', 'innovations'), 1),
#  (('evo', 'speedgoat', 'key', 'innovations', 'detailsvery'), 1),
#  (('speedgoat', 'key', 'innovations', 'detailsvery', 'low'), 1),
#  (('key', 'innovations', 'detailsvery', 'low', 'weight'), 1),
#  (('innovations', 'detailsvery', 'low', 'weight', 'coming'), 1),
#  (('detailsvery', 'low', 'weight', 'coming', '8 9'), 1),
#  (('low', 'weight', 'coming', '8 9', 'oz'), 1),
#  (('weight', 'coming', '8 9', 'oz', '252g'), 1),
#  (('coming', '8 9', 'oz', '252g', '33mm'), 1),
#  (('8 9', 'oz', '252g', '33mm', 'heel'), 1),
#  (('oz', '252g', '33mm', 'heel', '29mm'), 1),
#  (('252g', '33mm', 'heel', '29mm', 'forefoot'), 1),
#  (('33mm', 'heel', '29mm', 'forefoot', '0 4'), 1),
#  (('heel', '29mm', 'forefoot', '0 4', 'oz'), 1),
#  (('29mm', 'forefoot', '0 4', 'oz', 'evo'), 1),
#  (('forefoot', '0 4', 'oz', 'evo', 'speedgoat'), 1),
#  (('0 4', 'oz', 'evo', 'speedgoat', '1mm'), 1),
#  (('oz', 'evo', 'speedgoat', '1mm', 'stack'), 1),
#  (('evo', 'speedgoat', '1mm', 'stack', 'similarly'), 1),
#  (('speedgoat', '1mm', 'stack', 'similarly', 'broad'), 1),
#  (('1mm', 'stack', 'similarly', 'broad', 'stable'), 1),
#  (('stack', 'similarly', 'broad', 'stable', 'platform'), 1),
#  (('similarly', 'broad', 'stable', 'platform', 'stack'), 1),
#  (('broad', 'stable', 'platform', 'stack', 'height'), 1),
#  (('stable', 'platform', 'stack', 'height', 'speedgoat'), 1),
#  (('platform', 'stack', 'height', 'speedgoat', '5'), 1),
#  (('stack', 'height', 'speedgoat', '5', 'weighs'), 1),
#  (('height', 'speedgoat', '5', 'weighs', '0 85'), 1),
#  (('speedgoat', '5', 'weighs', '0 85', 'oz'), 1),
#  (('5', 'weighs', '0 85', 'oz', '24g'), 1),
#  (('weighs', '0 85', 'oz', '24g', 'more supercritical'), 1),
#  (('0 85', 'oz', '24g', 'more supercritical', 'eva'), 1),
#  (('oz', '24g', 'more supercritical', 'eva', 'foam'), 1),
#  (('24g', 'more supercritical', 'eva', 'foam', 'primary'), 1),
#  (('more supercritical', 'eva', 'foam', 'primary', 'cushion'), 1),
#  (('eva', 'foam', 'primary', 'cushion', 'provided'), 1),
#  (('foam', 'primary', 'cushion', 'provided', 'carbon'), 1),
#  (('primary', 'cushion', 'provided', 'carbon', '3'), 1),
#  (('cushion', 'provided', 'carbon', '3', 'light'), 1),
#  (('provided', 'carbon', '3', 'light', 'springy'), 1),
#  (('carbon', '3', 'light', 'springy', 'foam'), 1),
#  (('3', 'light', 'springy', 'foam', 'dual'), 1),
#  (('light', 'springy', 'foam', 'dual', 'density'), 1),
#  (('springy', 'foam', 'dual', 'density', 'proflyx'), 1),
#  (('foam', 'dual', 'density', 'proflyx', 'construction'), 1),
#  (('dual', 'density', 'proflyx', 'construction', 'softer'), 1),
#  (('density', 'proflyx', 'construction', 'softer', 'foam'), 1),
#  (('proflyx', 'construction', 'softer', 'foam', 'directly'), 1),
#  (('construction', 'softer', 'foam', 'directly', 'underfoot dual'), 1),
#  (('softer', 'foam', 'directly', 'underfoot dual', 'parallel'), 1),
#  (('foam', 'directly', 'underfoot dual', 'parallel', 'carbon'), 1),
#  (('directly', 'underfoot dual', 'parallel', 'carbon', 'plates'), 1),
#  (('underfoot dual', 'parallel', 'carbon', 'plates', 'provide'), 1),
#  (('parallel', 'carbon', 'plates', 'provide', 'forward'), 1),
#  (('carbon', 'plates', 'provide', 'forward', 'lateral'), 1),
#  (('plates', 'provide', 'forward', 'lateral', 'flex'), 1),
#  (('provide', 'forward', 'lateral', 'flex', 'springy'), 1),
#  (('forward', 'lateral', 'flex', 'springy', 'impulsevibram'), 1),
#  (('lateral', 'flex', 'springy', 'impulsevibram', 'megagrip'), 1),
#  (('flex', 'springy', 'impulsevibram', 'megagrip', 'litebase'), 1),
#  (('springy', 'impulsevibram', 'megagrip', 'litebase', '4mm'), 1),
#  (('impulsevibram', 'megagrip', 'litebase', '4mm', 'lugs hoka'), 1),
#  (('megagrip', 'litebase', '4mm', 'lugs hoka', 'positioning'), 1),
#  (('litebase', '4mm', 'lugs hoka', 'positioning', 'tecton'), 1),
#  (('4mm', 'lugs hoka', 'positioning', 'tecton', 'fast'), 1),
#  (('lugs hoka', 'positioning', 'tecton', 'fast', 'terrain'), 1),
#  (('positioning', 'tecton', 'fast', 'terrain', 'race'), 1),
#  (('tecton', 'fast', 'terrain', 'race', 'training'), 1),
#  (('fast', 'terrain', 'race', 'training', 'companion'), 1),
#  (('terrain', 'race', 'training', 'companion', 'speedgoat'), 1),
#  (('race', 'training', 'companion', 'speedgoat', 'leans'), 1),
#  (('training', 'companion', 'speedgoat', 'leans', 'training'), 1),
#  (('companion', 'speedgoat', 'leans', 'training', 'race'), 1),
#  (('speedgoat', 'leans', 'training', 'race', 'ultras the'), 1),
#  (('leans', 'training', 'race', 'ultras the', 'result'), 1),
#  (('training', 'race', 'ultras the', 'result', 'appears'), 1),
#  (('race', 'ultras the', 'result', 'appears', 'super'), 1),
#  (('ultras the', 'result', 'appears', 'super', 'light'), 1),
#  (('result', 'appears', 'super', 'light', 'super'), 1),
#  (('appears', 'super', 'light', 'super', 'stable'), 1),
#  (('super', 'light', 'super', 'stable', 'carbon'), 1),
#  (('light', 'super', 'stable', 'carbon', 'powered'), 1),
#  (('super', 'stable', 'carbon', 'powered', 'trail'), 1),
#  (('stable', 'carbon', 'powered', 'trail', 'racing'), 1),
#  (('carbon', 'powered', 'trail', 'racing', 'training'), 1),
#  (('powered', 'trail', 'racing', 'training', 'machine'), 1),
#  (('trail', 'racing', 'training', 'machine', 'eager'), 1),
#  (('racing', 'training', 'machine', 'eager', 'test'), 1),
#  (('training', 'machine', 'eager', 'test', 'multiple'), 1),
#  (('machine', 'eager', 'test', 'multiple', 'surfaces'), 1),
#  (('eager', 'test', 'multiple', 'surfaces', 'including'), 1),
#  (('test', 'multiple', 'surfaces', 'including', 'dirt'), 1),
#  (('multiple', 'surfaces', 'including', 'dirt', 'snow'), 1),
#  (('surfaces', 'including', 'dirt', 'snow', 'pavement'), 1),
#  (('including', 'dirt', 'snow', 'pavement', 'mud pros'), 1),
#  (('dirt', 'snow', 'pavement', 'mud pros', 'leading'), 1),
#  (('snow', 'pavement', 'mud pros', 'leading', 'trail'), 1),
#  (('pavement', 'mud pros', 'leading', 'trail', 'weight'), 1),
#  (('mud pros', 'leading', 'trail', 'weight', 'cushion'), 1),
#  (('leading', 'trail', 'weight', 'cushion', 'ratio'), 1),
#  (('trail', 'weight', 'cushion', 'ratio', 'sam jeff'), 1),
#  (('weight', 'cushion', 'ratio', 'sam jeff', 'v mike'), 1),
#  (('cushion', 'ratio', 'sam jeff', 'v mike', 'pcarbon'), 1),
#  (('ratio', 'sam jeff', 'v mike', 'pcarbon', 'trails'), 1),
#  (('sam jeff', 'v mike', 'pcarbon', 'trails', 'roads'), 1),
#  (('v mike', 'pcarbon', 'trails', 'roads', 'rigid'), 1),
#  (('pcarbon', 'trails', 'roads', 'rigid', 'terrain'), 1),
#  (('trails', 'roads', 'rigid', 'terrain', 'conforming'), 1),
#  (('roads', 'rigid', 'terrain', 'conforming', 'felt'), 1),
#  (('rigid', 'terrain', 'conforming', 'felt', 'impulse'), 1),
#  (('terrain', 'conforming', 'felt', 'impulse', 'protection'), 1),
#  (('conforming', 'felt', 'impulse', 'protection', 'sam jeff'), 1),
#  (('felt', 'impulse', 'protection', 'sam jeff', 'v mike'), 1),
#  (('impulse', 'protection', 'sam jeff', 'v mike', 'pdynamic'), 1),
#  (('protection', 'sam jeff', 'v mike', 'pdynamic', 'springy'), 1),
#  (('sam jeff', 'v mike', 'pdynamic', 'springy', 'firmer'), 1),
#  (('v mike', 'pdynamic', 'springy', 'firmer', 'cushioned'), 1),
#  (('pdynamic', 'springy', 'firmer', 'cushioned', 'ride'), 1),
#  (('springy', 'firmer', 'cushioned', 'ride', 'plenty'), 1),
#  (('firmer', 'cushioned', 'ride', 'plenty', 'protection'), 1),
#  (('cushioned', 'ride', 'plenty', 'protection', 'sam jeff'), 1),
#  (('ride', 'plenty', 'protection', 'sam jeff', 'vlight'), 1),
#  (('plenty', 'protection', 'sam jeff', 'vlight', 'protective'), 1),
#  (('protection', 'sam jeff', 'vlight', 'protective', 'comfortable'), 1),
#  (('sam jeff', 'vlight', 'protective', 'comfortable', 'upper'), 1),
#  (('vlight', 'protective', 'comfortable', 'upper', 'sam jeff'), 1),
#  (('protective', 'comfortable', 'upper', 'sam jeff', 'v mike'), 1),
#  (('comfortable', 'upper', 'sam jeff', 'v mike', 'psurprisingly'), 1),
#  (('upper', 'sam jeff', 'v mike', 'psurprisingly', 'stable'), 1),
#  (('sam jeff', 'v mike', 'psurprisingly', 'stable', 'technical'), 1),
#  (('v mike', 'psurprisingly', 'stable', 'technical', 'terran'), 1),
#  (('psurprisingly', 'stable', 'technical', 'terran', 'mike'), 1),
#  (('stable', 'technical', 'terran', 'mike', 'pcons'), 1),
#  (('technical', 'terran', 'mike', 'pcons', 'priced'), 1),
#  (('terran', 'mike', 'pcons', 'priced', 'carbon'), 1),
#  (('mike', 'pcons', 'priced', 'carbon', 'plated'), 1),
#  (('pcons', 'priced', 'carbon', 'plated', 'shoes'), 1),
#  (('priced', 'carbon', 'plated', 'shoes', 'tend'), 1),
#  (('carbon', 'plated', 'shoes', 'tend', '200'), 1),
#  (('plated', 'shoes', 'tend', '200', 'sam jeff'), 1),
#  (('shoes', 'tend', '200', 'sam jeff', 'vupper'), 1),
#  (('tend', '200', 'sam jeff', 'vupper', 'hold'), 1),
#  (('200', 'sam jeff', 'vupper', 'hold', 'suffer'), 1),
#  (('sam jeff', 'vupper', 'hold', 'suffer', 'bit'), 1),
#  (('vupper', 'hold', 'suffer', 'bit', 'highly'), 1),
#  (('hold', 'suffer', 'bit', 'highly', 'technical'), 1),
#  (('suffer', 'bit', 'highly', 'technical', 'terrain jeff'), 1),
#  (('bit', 'highly', 'technical', 'terrain jeff', 'vmidsole'), 1),
#  (('highly', 'technical', 'terrain jeff', 'vmidsole', 'bit'), 1),
#  (('technical', 'terrain jeff', 'vmidsole', 'bit', 'firm'), 1),
#  (('terrain jeff', 'vmidsole', 'bit', 'firm', 'fast'), 1),
#  (('vmidsole', 'bit', 'firm', 'fast', 'downhills jeff'), 1),
#  (('bit', 'firm', 'fast', 'downhills jeff', 'vsnug'), 1),
#  (('firm', 'fast', 'downhills jeff', 'vsnug', 'race type'), 1),
#  (('fast', 'downhills jeff', 'vsnug', 'race type', 'upper'), 1),
#  (('downhills jeff', 'vsnug', 'race type', 'upper', 'fit'), 1),
#  (('vsnug', 'race type', 'upper', 'fit', 'size'), 1),
#  (('race type', 'upper', 'fit', 'size', 'mike'), 1),
#  (('upper', 'fit', 'size', 'mike', 'pstatsapprox'), 1),
#  (('fit', 'size', 'mike', 'pstatsapprox', 'weight'), 1),
#  (('size', 'mike', 'pstatsapprox', 'weight', 'men'), 1),
#  (('mike', 'pstatsapprox', 'weight', 'men', ' s'), 1),
#  (('pstatsapprox', 'weight', 'men', ' s', '8 9'), 1),
#  (('weight', 'men', ' s', '8 9', 'oz'), 1),
#  (('men', ' s', '8 9', 'oz', '252'), 1),
#  ((' s', '8 9', 'oz', '252', 'us9'), 1),
#  (('8 9', 'oz', '252', 'us9', 'women'), 1),
#  (('oz', '252', 'us9', 'women', ' s'), 1),
#  (('252', 'us9', 'women', ' s', 'oz'), 1),
#  (('us9', 'women', ' s', 'oz', 'us8'), 1),
#  (('women', ' s', 'oz', 'us8', 'samples'), 1),
#  ((' s', 'oz', 'us8', 'samples', 'men'), 1),
#  (('oz', 'us8', 'samples', 'men', '8 65'), 1),
#  (('us8', 'samples', 'men', '8 65', 'oz'), 1),
#  (('samples', 'men', '8 65', 'oz', '244'), 1),
#  (('men', '8 65', 'oz', '244', 'us8 5'), 1),
#  (('8 65', 'oz', '244', 'us8 5', '9 5'), 1),
#  (('oz', '244', 'us8 5', '9 5', 'oz'), 1),
#  (('244', 'us8 5', '9 5', 'oz', '268'), 1),
#  (('us8 5', '9 5', 'oz', '268', 'us9 5'), 1),
#  (('9 5', 'oz', '268', 'us9 5', 'evo'), 1),
#  (('oz', '268', 'us9 5', 'evo', 'speedgoat'), 1),
#  (('268', 'us9 5', 'evo', 'speedgoat', 'us8 5'), 1),
#  (('us9 5', 'evo', 'speedgoat', 'us8 5', 'weighs'), 1),
#  (('evo', 'speedgoat', 'us8 5', 'weighs', '9 06'), 1),
#  (('speedgoat', 'us8 5', 'weighs', '9 06', 'oz'), 1),
#  (('us8 5', 'weighs', '9 06', 'oz', '257g'), 1),
#  (('weighs', '9 06', 'oz', '257g', 'stack'), 1),
#  (('9 06', 'oz', '257g', 'stack', 'height'), 1),
#  (('oz', '257g', 'stack', 'height', 'men'), 1),
#  (('257g', 'stack', 'height', 'men', '33'), 1),
#  (('stack', 'height', 'men', '33', 'mm'), 1),
#  (('height', 'men', '33', 'mm', 'heel'), 1),
#  (('men', '33', 'mm', 'heel', '29mm'), 1),
#  (('33', 'mm', 'heel', '29mm', 'forefoot'), 1),
#  (('mm', 'heel', '29mm', 'forefoot', 'including'), 1),
#  (('heel', '29mm', 'forefoot', 'including', 'partners'), 1),
#  (('29mm', 'forefoot', 'including', 'partners', 'end'), 1),
#  (('forefoot', 'including', 'partners', 'end', 'article'), 1),
#  (('including', 'partners', 'end', 'article', '200'), 1),
#  (('partners', 'end', 'article', '200', 'impressions'), 1),
#  (('end', 'article', '200', 'impressions', 'fit'), 1),
#  (('article', '200', 'impressions', 'fit', 'uppersam'), 1),
#  (('200', 'impressions', 'fit', 'uppersam', 'striking'), 1),
#  (('impressions', 'fit', 'uppersam', 'striking', 'orange'), 1),
#  (('fit', 'uppersam', 'striking', 'orange', 'dark'), 1),
#  (('uppersam', 'striking', 'orange', 'dark', 'blue'), 1),
#  (('striking', 'orange', 'dark', 'blue', 'screams'), 1),
#  (('orange', 'dark', 'blue', 'screams', 'speed'), 1),
#  (('dark', 'blue', 'screams', 'speed', 'immediately'), 1),
#  (('blue', 'screams', 'speed', 'immediately', 'noticeable'), 1),
#  (('screams', 'speed', 'immediately', 'noticeable', 'light'), 1),
#  (('speed', 'immediately', 'noticeable', 'light', 'big'), 1),
#  (('immediately', 'noticeable', 'light', 'big', 'shoe'), 1),
#  (('noticeable', 'light', 'big', 'shoe', 'light'), 1),
#  (('light', 'big', 'shoe', 'light', 'hand'), 1),
#  (('big', 'shoe', 'light', 'hand', 'big'), 1),
#  (('shoe', 'light', 'hand', 'big', 'stack'), 1),
#  (('light', 'hand', 'big', 'stack', 'shoe the'), 1),
#  (('hand', 'big', 'stack', 'shoe the', 'upper'), 1),
#  (('big', 'stack', 'shoe the', 'upper', 'jacquard'), 1),
#  (('stack', 'shoe the', 'upper', 'jacquard', 'engineered'), 1),
#  (('shoe the', 'upper', 'jacquard', 'engineered', 'mesh'), 1),
#  (('upper', 'jacquard', 'engineered', 'mesh', 'thin'), 1),
#  (('jacquard', 'engineered', 'mesh', 'thin', 'gusset'), 1),
#  (('engineered', 'mesh', 'thin', 'gusset', 'tongue'), 1),
#  (('mesh', 'thin', 'gusset', 'tongue', 'stout'), 1),
#  (('thin', 'gusset', 'tongue', 'stout', 'short'), 1),
#  (('gusset', 'tongue', 'stout', 'short', 'toe'), 1),
#  (('tongue', 'stout', 'short', 'toe', 'bumper rand'), 1),
#  (('stout', 'short', 'toe', 'bumper rand', 'overlays'), 1),
#  (('short', 'toe', 'bumper rand', 'overlays', 'upper'), 1),
#  (('toe', 'bumper rand', 'overlays', 'upper', 'durability'), 1),
#  (('bumper rand', 'overlays', 'upper', 'durability', 'remains'), 1),
#  (('overlays', 'upper', 'durability', 'remains', 'recall'), 1),
#  (('upper', 'durability', 'remains', 'recall', 'race'), 1),
#  (('durability', 'remains', 'recall', 'race', 'focused'), 1),
#  (('remains', 'recall', 'race', 'focused', 'shoe the'), 1),
#  (('recall', 'race', 'focused', 'shoe the', 'fit'), 1),
#  (('race', 'focused', 'shoe the', 'fit', 'true'), 1),
#  (('focused', 'shoe the', 'fit', 'true', 'size'), 1),
#  (('shoe the', 'fit', 'true', 'size', 'soft'), 1),
#  (('fit', 'true', 'size', 'soft', 'toe'), 1),
#  (('true', 'size', 'soft', 'toe', 'box'), 1),
#  (('size', 'soft', 'toe', 'box', 'pliable'), 1),
#  (('soft', 'toe', 'box', 'pliable', 'thin'), 1),
#  (('toe', 'box', 'pliable', 'thin', 'mesh'), 1),
#  (('box', 'pliable', 'thin', 'mesh', 'plenty'), 1),
#  (('pliable', 'thin', 'mesh', 'plenty', 'foot'), 1),
#  (('thin', 'mesh', 'plenty', 'foot', 'splay'), 1),
#  (('mesh', 'plenty', 'foot', 'splay', 'medium'), 1),
#  (('plenty', 'foot', 'splay', 'medium', 'narrower'), 1),
#  (('foot', 'splay', 'medium', 'narrower', 'feet'), 1),
#  (('splay', 'medium', 'narrower', 'feet', 'lace'), 1),
#  (('medium', 'narrower', 'feet', 'lace', 'pattern'), 1),
#  (('narrower', 'feet', 'lace', 'pattern', 'reaches'), 1),
#  (('feet', 'lace', 'pattern', 'reaches', 'toe'), 1),
#  (('lace', 'pattern', 'reaches', 'toe', 'unlike'), 1),
#  (('pattern', 'reaches', 'toe', 'unlike', 'speedgoats'), 1),
#  (('reaches', 'toe', 'unlike', 'speedgoats', 'toe'), 1),
#  (('toe', 'unlike', 'speedgoats', 'toe', 'stretch'), 1),
#  (('unlike', 'speedgoats', 'toe', 'stretch', 'inset'), 1),
#  (('speedgoats', 'toe', 'stretch', 'inset', 'easy'), 1),
#  (('toe', 'stretch', 'inset', 'easy', 'pull'), 1),
#  (('stretch', 'inset', 'easy', 'pull', 'lightly'), 1),
#  (('inset', 'easy', 'pull', 'lightly', 'padded'), 1),
#  (('easy', 'pull', 'lightly', 'padded', 'breathable'), 1),
#  (('pull', 'lightly', 'padded', 'breathable', 'tongue'), 1),
#  (('lightly', 'padded', 'breathable', 'tongue', 'grid'), 1),
#  (('padded', 'breathable', 'tongue', 'grid', 'mesh'), 1),
#  (('breathable', 'tongue', 'grid', 'mesh', 'top'), 1),
#  (('tongue', 'grid', 'mesh', 'top', 'slightly'), 1),
#  (('grid', 'mesh', 'top', 'slightly', 'stretchy'), 1),
#  (('mesh', 'top', 'slightly', 'stretchy', 'picture'), 1),
#  (('top', 'slightly', 'stretchy', 'picture', 'notice'), 1),
#  (('slightly', 'stretchy', 'picture', 'notice', 'baggier'), 1),
#  (('stretchy', 'picture', 'notice', 'baggier', 'evo'), 1),
#  (('picture', 'notice', 'baggier', 'evo', 'speedgoat'), 1),
#  (('notice', 'baggier', 'evo', 'speedgoat', ' s'), 1),
#  (('baggier', 'evo', 'speedgoat', ' s', 'toe'), 1),
#  (('evo', 'speedgoat', ' s', 'toe', 'box'), 1),
#  (('speedgoat', ' s', 'toe', 'box', 'size i'), 1),
#  ((' s', 'toe', 'box', 'size i', 'light'), 1),
#  (('toe', 'box', 'size i', 'light', 'pliable'), 1),
#  (('box', 'size i', 'light', 'pliable', 'mesh'), 1),
#  (('size i', 'light', 'pliable', 'mesh', 'stretch'), 1),
#  (('light', 'pliable', 'mesh', 'stretch', 'piece'), 1),
#  (('pliable', 'mesh', 'stretch', 'piece', 'front'), 1),
#  (('mesh', 'stretch', 'piece', 'front', 'compromise'), 1),
#  (('stretch', 'piece', 'front', 'compromise', 'hold'), 1),
#  (('piece', 'front', 'compromise', 'hold', 'mesh'), 1),
#  (('front', 'compromise', 'hold', 'mesh', 'wider'), 1),
#  (('compromise', 'hold', 'mesh', 'wider', 'feet'), 1),
#  (('hold', 'mesh', 'wider', 'feet', 'accommodated'), 1),
#  (('mesh', 'wider', 'feet', 'accommodated', 'keeping'), 1),
#  (('wider', 'feet', 'accommodated', 'keeping', 'front'), 1),
#  (('feet', 'accommodated', 'keeping', 'front', 'lacing'), 1),
#  (('accommodated', 'keeping', 'front', 'lacing', 'front'), 1),
#  (('keeping', 'front', 'lacing', 'front', 'bit'), 1),
#  (('front', 'lacing', 'front', 'bit', 'looser'), 1),
#  (('lacing', 'front', 'bit', 'looser', 'mid'), 1),
#  (('front', 'bit', 'looser', 'mid', 'foot'), 1),
#  (('bit', 'looser', 'mid', 'foot', 'hold'), 1),
#  (('looser', 'mid', 'foot', 'hold', 'solid'), 1),
#  (('mid', 'foot', 'hold', 'solid', 'upper'), 1),
#  (('foot', 'hold', 'solid', 'upper', 'supportive'), 1),
#  (('hold', 'solid', 'upper', 'supportive', 'evo'), 1),
#  (('solid', 'upper', 'supportive', 'evo', 'speedgoat'), 1),
#  (('upper', 'supportive', 'evo', 'speedgoat', 'lighter'), 1),
#  (('supportive', 'evo', 'speedgoat', 'lighter', 'trail'), 1),
#  (('evo', 'speedgoat', 'lighter', 'trail', 'race'), 1),
#  (('speedgoat', 'lighter', 'trail', 'race', 'upper'), 1),
#  (('lighter', 'trail', 'race', 'upper', 'category'), 1),
#  (('trail', 'race', 'upper', 'category', 'reminds'), 1),
#  (('race', 'upper', 'category', 'reminds', 'upper'), 1),
#  (('upper', 'category', 'reminds', 'upper', 'fit'), 1),
#  (('category', 'reminds', 'upper', 'fit', 'roomier'), 1),
#  (('reminds', 'upper', 'fit', 'roomier', 'zinal'), 1),
#  (('upper', 'fit', 'roomier', 'zinal', 'seemingly'), 1),
#  (('fit', 'roomier', 'zinal', 'seemingly', 'light'), 1),
#  (('roomier', 'zinal', 'seemingly', 'light', 'pliable'), 1),
#  (('zinal', 'seemingly', 'light', 'pliable', 'upper'), 1),
#  (('seemingly', 'light', 'pliable', 'upper', 'works'), 1),
#  (('light', 'pliable', 'upper', 'works', 'heel'), 1),
#  (('pliable', 'upper', 'works', 'heel', 'counter'), 1),
#  (('upper', 'works', 'heel', 'counter', 'pliable'), 1),
#  (('works', 'heel', 'counter', 'pliable', 'low'), 1),
#  (('heel', 'counter', 'pliable', 'low', 'stiffer'), 1),
#  (('counter', 'pliable', 'low', 'stiffer', 'rigid'), 1),
#  (('pliable', 'low', 'stiffer', 'rigid', 'heel'), 1),
#  (('low', 'stiffer', 'rigid', 'heel', 'counter'), 1),
#  (('stiffer', 'rigid', 'heel', 'counter', 'heel'), 1),
#  (('rigid', 'heel', 'counter', 'heel', 'hold'), 1),
#  (('heel', 'counter', 'heel', 'hold', 'good'), 1),
#  (('counter', 'heel', 'hold', 'good', 'super'), 1),
#  (('heel', 'hold', 'good', 'super', 'technical'), 1),
#  (('hold', 'good', 'super', 'technical', 'terrain'), 1),
#  (('good', 'super', 'technical', 'terrain', 'bombproof jeff'), 1),
#  (('super', 'technical', 'terrain', 'bombproof jeff', 'bright'), 1),
#  (('technical', 'terrain', 'bombproof jeff', 'bright', 'orange'), 1),
#  (('terrain', 'bombproof jeff', 'bright', 'orange', 'colorway'), 1),
#  (('bombproof jeff', 'bright', 'orange', 'colorway', 'classy'), 1),
#  (('bright', 'orange', 'colorway', 'classy', 'strip'), 1),
#  (('orange', 'colorway', 'classy', 'strip', 'blue'), 1),
#  (('colorway', 'classy', 'strip', 'blue', 'upper'), 1),
#  (('classy', 'strip', 'blue', 'upper', 'midsole'), 1),
#  (('strip', 'blue', 'upper', 'midsole', 'striking'), 1),
#  (('blue', 'upper', 'midsole', 'striking', 'fast'), 1),
#  (('upper', 'midsole', 'striking', 'fast', 'stating'), 1),
#  (('midsole', 'striking', 'fast', 'stating', 'shoe'), 1),
#  (('striking', 'fast', 'stating', 'shoe', 'means'), 1),
#  (('fast', 'stating', 'shoe', 'means', 'business'), 1),
#  (('stating', 'shoe', 'means', 'business', 'find'), 1),
#  (('shoe', 'means', 'business', 'find', 'tecton'), 1),
#  (('means', 'business', 'find', 'tecton', 'bit'), 1),
#  (('business', 'find', 'tecton', 'bit', 'larger'), 1),
#  (('find', 'tecton', 'bit', 'larger', 'expected'), 1),
#  (('tecton', 'bit', 'larger', 'expected', 'hoka'), 1),
#  (('bit', 'larger', 'expected', 'hoka', 'expected'), 1),
#  (('larger', 'expected', 'hoka', 'expected', 'smaller'), 1),
#  (('expected', 'hoka', 'expected', 'smaller', 'shoe'), 1),
#  (('hoka', 'expected', 'smaller', 'shoe', 'zinal'), 1),
#  (('expected', 'smaller', 'shoe', 'zinal', 'compared'), 1),
#  (('smaller', 'shoe', 'zinal', 'compared', 'shoes'), 1),
#  (('shoe', 'zinal', 'compared', 'shoes', 'class'), 1),
#  (('zinal', 'compared', 'shoes', 'class', 'necessarily'), 1),
#  (('compared', 'shoes', 'class', 'necessarily', 'larger'), 1),
#  (('shoes', 'class', 'necessarily', 'larger', 'tecton'), 1),
#  (('class', 'necessarily', 'larger', 'tecton', 'light'), 1),
#  (('necessarily', 'larger', 'tecton', 'light', 'hand'), 1),
#  (('larger', 'tecton', 'light', 'hand', 'light'), 1),
#  (('tecton', 'light', 'hand', 'light', 'foot'), 1),
#  (('light', 'hand', 'light', 'foot', 'stack'), 1),
#  (('hand', 'light', 'foot', 'stack', 'height fit'), 1),
#  (('light', 'foot', 'stack', 'height fit', 'true'), 1),
#  (('foot', 'stack', 'height fit', 'true', 'size'), 1),
#  (('stack', 'height fit', 'true', 'size', 'line'), 1),
#  (('height fit', 'true', 'size', 'line', 'size'), 1),
#  (('true', 'size', 'line', 'size', '10'), 1),
#  (('size', 'line', 'size', '10', 'hoka'), 1),
#  (('line', 'size', '10', 'hoka', 'jacquard'), 1),
#  (('size', '10', 'hoka', 'jacquard', 'engineered'), 1),
#  (('10', 'hoka', 'jacquard', 'engineered', 'mesh'), 1),
#  (('hoka', 'jacquard', 'engineered', 'mesh', 'upper'), 1),
#  (('jacquard', 'engineered', 'mesh', 'upper', 'flexible'), 1),
#  (('engineered', 'mesh', 'upper', 'flexible', 'premium'), 1),
#  (('mesh', 'upper', 'flexible', 'premium', 'feeling'), 1),
#  (('upper', 'flexible', 'premium', 'feeling', 'construction'), 1),
#  (('flexible', 'premium', 'feeling', 'construction', 'feels'), 1),
#  (('premium', 'feeling', 'construction', 'feels', 'secure'), 1),
#  (('feeling', 'construction', 'feels', 'secure', 'excellent'), 1),
#  (('construction', 'feels', 'secure', 'excellent', 'lockdown'), 1),
#  (('feels', 'secure', 'excellent', 'lockdown', 'midfoot'), 1),
#  (('secure', 'excellent', 'lockdown', 'midfoot', 'assisted'), 1),
#  (('excellent', 'lockdown', 'midfoot', 'assisted', 'secure'), 1),
#  (('lockdown', 'midfoot', 'assisted', 'secure', 'lacing'), 1),
#  (('midfoot', 'assisted', 'secure', 'lacing', 'jacquard'), 1),
#  (('assisted', 'secure', 'lacing', 'jacquard', 'weave'), 1),
#  (('secure', 'lacing', 'jacquard', 'weave', 'thick'), 1),
#  (('lacing', 'jacquard', 'weave', 'thick', 'dense'), 1),
#  (('jacquard', 'weave', 'thick', 'dense', 'feels'), 1),
#  (('weave', 'thick', 'dense', 'feels', 'durable'), 1),
#  (('thick', 'dense', 'feels', 'durable', 'adds'), 1),
#  (('dense', 'feels', 'durable', 'adds', 'secure'), 1),
#  (('feels', 'durable', 'adds', 'secure', 'butit'), 1),
#  (('durable', 'adds', 'secure', 'butit', 'breathable'), 1),
#  (('adds', 'secure', 'butit', 'breathable', 'forefoot'), 1),
#  (('secure', 'butit', 'breathable', 'forefoot', 'slightly'), 1),
#  (('butit', 'breathable', 'forefoot', 'slightly', 'accommodating'), 1),
#  (('breathable', 'forefoot', 'slightly', 'accommodating', 'narrow'), 1),
#  (('forefoot', 'slightly', 'accommodating', 'narrow', 'foot'), 1),
#  (('slightly', 'accommodating', 'narrow', 'foot', 'lacing'), 1),
#  (('accommodating', 'narrow', 'foot', 'lacing', 'leeway'), 1),
#  (('narrow', 'foot', 'lacing', 'leeway', 'crank'), 1),
#  (('foot', 'lacing', 'leeway', 'crank', 'laces'), 1),
#  (('lacing', 'leeway', 'crank', 'laces', 'snug'), 1),
#  (('leeway', 'crank', 'laces', 'snug', 'liking'), 1),
#  (('crank', 'laces', 'snug', 'liking', 'technical'), 1),
#  (('laces', 'snug', 'liking', 'technical', 'terrain'), 1),
#  (('snug', 'liking', 'technical', 'terrain', 'relax'), 1),
#  (('liking', 'technical', 'terrain', 'relax', 'laces'), 1),
#  (('technical', 'terrain', 'relax', 'laces', 'bit'), 1),
#  (('terrain', 'relax', 'laces', 'bit', 'bit'), 1),
#  (('relax', 'laces', 'bit', 'bit', 'wiggle'), 1),
#  (('laces', 'bit', 'bit', 'wiggle', 'room'), 1),
#  (('bit', 'bit', 'wiggle', 'room', 'longer'), 1),
#  (('bit', 'wiggle', 'room', 'longer', 'runs'), 1),
#  (('wiggle', 'room', 'longer', 'runs', 'heel'), 1),
#  (('room', 'longer', 'runs', 'heel', 'counter'), 1),
#  (('longer', 'runs', 'heel', 'counter', 'malleable'), 1),
#  (('runs', 'heel', 'counter', 'malleable', 'comfortable'), 1),
#  (('heel', 'counter', 'malleable', 'comfortable', 'supportive'), 1),
#  (('counter', 'malleable', 'comfortable', 'supportive', 'run'), 1),
#  (('malleable', 'comfortable', 'supportive', 'run', 'notice'), 1),
#  (('comfortable', 'supportive', 'run', 'notice', 'bit'), 1),
#  (('supportive', 'run', 'notice', 'bit', 'heel'), 1),
#  (('run', 'notice', 'bit', 'heel', 'lift'), 1),
#  (('notice', 'bit', 'heel', 'lift', 'stopped'), 1),
#  (('bit', 'heel', 'lift', 'stopped', 're lace'), 1),
#  (('heel', 'lift', 'stopped', 're lace', 'change'), 1),
#  (('lift', 'stopped', 're lace', 'change', 'extra'), 1),
#  (('stopped', 're lace', 'change', 'extra', 'rear'), 1),
#  (('re lace', 'change', 'extra', 'rear', 'eyelet'), 1),
#  (('change', 'extra', 'rear', 'eyelet', 'helped'), 1),
#  (('extra', 'rear', 'eyelet', 'helped', 'lot'), 1),
#  (('rear', 'eyelet', 'helped', 'lot', 'heel'), 1),
#  (('eyelet', 'helped', 'lot', 'heel', 'lift'), 1),
#  (('helped', 'lot', 'heel', 'lift', 'fit'), 1),
#  (('lot', 'heel', 'lift', 'fit', 'sizing'), 1),
#  (('heel', 'lift', 'fit', 'sizing', 'toes'), 1),
#  (('lift', 'fit', 'sizing', 'toes', 'room'), 1),
#  (('fit', 'sizing', 'toes', 'room', 'mentioned'), 1),
#  (('sizing', 'toes', 'room', 'mentioned', 'extra'), 1),
#  (('toes', 'room', 'mentioned', 'extra', 'eyelet'), 1),
#  (('room', 'mentioned', 'extra', 'eyelet', 'helps'), 1),
#  (('mentioned', 'extra', 'eyelet', 'helps', 'lock'), 1),
#  (('extra', 'eyelet', 'helps', 'lock', 'heel'), 1),
#  (('eyelet', 'helps', 'lock', 'heel', 'lace'), 1),
#  (('helps', 'lock', 'heel', 'lace', 'lock'), 1),
#  (('lock', 'heel', 'lace', 'lock', 'reason'), 1),
#  (('heel', 'lace', 'lock', 'reason', 'lift'), 1),
#  (('lace', 'lock', 'reason', 'lift', 'exacerbated'), 1),
#  (('lock', 'reason', 'lift', 'exacerbated', 'stiffness'), 1),
#  (('reason', 'lift', 'exacerbated', 'stiffness', 'carbon'), 1),
#  (('lift', 'exacerbated', 'stiffness', 'carbon', 'plates'), 1),
#  (('exacerbated', 'stiffness', 'carbon', 'plates', 'noticed'), 1),
#  (('stiffness', 'carbon', 'plates', 'noticed', 'heel'), 1),
#  (('carbon', 'plates', 'noticed', 'heel', 'lift'), 1),
#  (('plates', 'noticed', 'heel', 'lift', 'running'), 1),
#  (('noticed', 'heel', 'lift', 'running', 'uphill'), 1),
#  (('heel', 'lift', 'running', 'uphill', ' mike'), 1),
#  (('lift', 'running', 'uphill', ' mike', 'bit'), 1),
#  (('running', 'uphill', ' mike', 'bit', 'late'), 1),
#  (('uphill', ' mike', 'bit', 'late', 'party'), 1),
#  ((' mike', 'bit', 'late', 'party', 'review'), 1),
#  (('bit', 'late', 'party', 'review', 've'), 1),
#  (('late', 'party', 'review', 've', 'raced'), 1),
#  (('party', 'review', 've', 'raced', 'won'), 1),
#  (('review', 've', 'raced', 'won', '100m'), 1),
#  (('ve', 'raced', 'won', '100m', 'trail'), 1),
#  (('raced', 'won', '100m', 'trail', 'ultras'), 1),
#  (('won', '100m', 'trail', 'ultras', 'tecton'), 1),
#  (('100m', 'trail', 'ultras', 'tecton', 'stanhope'), 1),
#  (('trail', 'ultras', 'tecton', 'stanhope', '100m'), 1),
#  (('ultras', 'tecton', 'stanhope', '100m', 'imtuf'), 1),
#  (('tecton', 'stanhope', '100m', 'imtuf', '100m'), 1),
#  (('stanhope', '100m', 'imtuf', '100m', 'races'), 1),
#  (('100m', 'imtuf', '100m', 'races', 'highly'), 1),
#  (('imtuf', '100m', 'races', 'highly', 'rugged'), 1),
#  (('100m', 'races', 'highly', 'rugged', 'idaho'), 1),
#  (('races', 'highly', 'rugged', 'idaho', 'mountain'), 1),
#  (('highly', 'rugged', 'idaho', 'mountain', 'terrain'), 1),
#  (('rugged', 'idaho', 'mountain', 'terrain', 'sam'), 1),
#  (('idaho', 'mountain', 'terrain', 'sam', 'jeff'), 1),
#  (('mountain', 'terrain', 'sam', 'jeff', 'covered'), 1),
#  (('terrain', 'sam', 'jeff', 'covered', 'ins'), 1),
#  (('sam', 'jeff', 'covered', 'ins', 'outs'), 1),
#  (('jeff', 'covered', 'ins', 'outs', 'shoe'), 1),
#  (('covered', 'ins', 'outs', 'shoe', 'initial'), 1),
#  (('ins', 'outs', 'shoe', 'initial', 'review'), 1),
#  (('outs', 'shoe', 'initial', 'review', 'll'), 1),
#  (('shoe', 'initial', 'review', 'll', 'focus'), 1),
#  (('initial', 'review', 'll', 'focus', 'added'), 1),
#  (('review', 'll', 'focus', 'added', 'thoughts'), 1),
#  (('ll', 'focus', 'added', 'thoughts', 'feelings'), 1),
#  (('focus', 'added', 'thoughts', 'feelings', 'based'), 1),
#  (('added', 'thoughts', 'feelings', 'based', 'race'), 1),
#  (('thoughts', 'feelings', 'based', 'race', 'experiences the'), 1),
#  (('feelings', 'based', 'race', 'experiences the', 'tecton'), 1),
#  (('based', 'race', 'experiences the', 'tecton', 'upper'), 1),
#  (('race', 'experiences the', 'tecton', 'upper', 'hoka'), 1),
#  (('experiences the', 'tecton', 'upper', 'hoka', 'trail'), 1),
#  (('tecton', 'upper', 'hoka', 'trail', 'upper'), 1),
#  (('upper', 'hoka', 'trail', 'upper', 'material'), 1),
#  (('hoka', 'trail', 'upper', 'material', 'thin'), 1),
#  (('trail', 'upper', 'material', 'thin', 'lightweight'), 1),
#  (('upper', 'material', 'thin', 'lightweight', 'overlay'), 1),
#  (('material', 'thin', 'lightweight', 'overlay', 'free'), 1),
#  (('thin', 'lightweight', 'overlay', 'free', 'thicker'), 1),
#  (('lightweight', 'overlay', 'free', 'thicker', 'multi layered'), 1),
#  (('overlay', 'free', 'thicker', 'multi layered', 'uppers'), 1),
#  (('free', 'thicker', 'multi layered', 'uppers', 'trail'), 1),
#  (('thicker', 'multi layered', 'uppers', 'trail', 'shoes'), 1),
#  (('multi layered', 'uppers', 'trail', 'shoes', 'find'), 1),
#  (('uppers', 'trail', 'shoes', 'find', 'upper'), 1),
#  (('trail', 'shoes', 'find', 'upper', 'wraps'), 1),
#  (('shoes', 'find', 'upper', 'wraps', 'foot'), 1),
#  (('find', 'upper', 'wraps', 'foot', 'extremely'), 1),
#  (('upper', 'wraps', 'foot', 'extremely', 'dial'), 1),
#  (('wraps', 'foot', 'extremely', 'dial', 'fit'), 1),
#  (('foot', 'extremely', 'dial', 'fit', 'laces'), 1),
#  (('extremely', 'dial', 'fit', 'laces', 'extend'), 1),
#  (('dial', 'fit', 'laces', 'extend', 'toes'), 1),
#  (('fit', 'laces', 'extend', 'toes', 'upper'), 1),
#  (('laces', 'extend', 'toes', 'upper', 'race fit'), 1),
#  (('extend', 'toes', 'upper', 'race fit', 'snug'), 1),
#  (('toes', 'upper', 'race fit', 'snug', 'extra'), 1),
#  (('upper', 'race fit', 'snug', 'extra', 'space'), 1),
#  (('race fit', 'snug', 'extra', 'space', 'shape'), 1),
#  (('snug', 'extra', 'space', 'shape', 'upper'), 1),
#  (('extra', 'space', 'shape', 'upper', 'resembles'), 1),
#  (('space', 'shape', 'upper', 'resembles', 'normal'), 1),
#  (('shape', 'upper', 'resembles', 'normal', 'foot'), 1),
#  (('upper', 'resembles', 'normal', 'foot', 'shape'), 1),
#  (('resembles', 'normal', 'foot', 'shape', 'helpful'), 1),
#  (('normal', 'foot', 'shape', 'helpful', 'terms'), 1),
#  (('foot', 'shape', 'helpful', 'terms', 'security'), 1),
#  (('shape', 'helpful', 'terms', 'security', 'upper'), 1),
#  (('helpful', 'terms', 'security', 'upper', 'dusty'), 1),
#  (('terms', 'security', 'upper', 'dusty', 'beat'), 1),
#  (('security', 'upper', 'dusty', 'beat', '100'), 1),
#  (('upper', 'dusty', 'beat', '100', 'hard'), 1),
#  (('dusty', 'beat', '100', 'hard', 'miles'), 1),
#  (('beat', '100', 'hard', 'miles', 'intact'), 1),
#  (('100', 'hard', 'miles', 'intact', 'blowouts'), 1),
#  (('hard', 'miles', 'intact', 'blowouts', 'sizing'), 1),
#  (('miles', 'intact', 'blowouts', 'sizing', 'wore'), 1),
#  (('intact', 'blowouts', 'sizing', 'wore', 'size'), 1),
#  (('blowouts', 'sizing', 'wore', 'size', '10 0'), 1),
#  (('sizing', 'wore', 'size', '10 0', 'standhope'), 1),
#  (('wore', 'size', '10 0', 'standhope', 'typical'), 1),
#  (('size', '10 0', 'standhope', 'typical', 'larger'), 1),
#  (('10 0', 'standhope', 'typical', 'larger', 'ultra'), 1),
#  (('standhope', 'typical', 'larger', 'ultra', 'size'), 1),
#  (('typical', 'larger', 'ultra', 'size', 'hokas'), 1),
#  (('larger', 'ultra', 'size', 'hokas', 'brands'), 1),
#  (('ultra', 'size', 'hokas', 'brands', 'snug'), 1),
#  (('size', 'hokas', 'brands', 'snug', 'race'), 1),
#  (('hokas', 'brands', 'snug', 'race', 'wore'), 1),
#  (('brands', 'snug', 'race', 'wore', 'uncomfortable'), 1),
#  (('snug', 'race', 'wore', 'uncomfortable', '⅓'), 1),
#  (('race', 'wore', 'uncomfortable', '⅓', 'race'), 1),
#  (('wore', 'uncomfortable', '⅓', 'race', 'foot'), 1),
#  (('uncomfortable', '⅓', 'race', 'foot', 'swelling'), 1),
#  (('⅓', 'race', 'foot', 'swelling', 'racing'), 1),
#  (('race', 'foot', 'swelling', 'racing', 'win'), 1),
#  (('foot', 'swelling', 'racing', 'win', 'didn'), 1),
#  (('swelling', 'racing', 'win', 'didn', 'change'), 1),
#  (('racing', 'win', 'didn', 'change', 'shoes'), 1),
#  (('win', 'didn', 'change', 'shoes', 'feet'), 1),
#  (('didn', 'change', 'shoes', 'feet', 'paid'), 1),
#  (('change', 'shoes', 'feet', 'paid', 'bit'), 1),
#  (('shoes', 'feet', 'paid', 'bit', 'price'), 1),
#  (('feet', 'paid', 'bit', 'price', 'imtuf'), 1),
#  (('paid', 'bit', 'price', 'imtuf', 'picked'), 1),
#  (('bit', 'price', 'imtuf', 'picked', 'pair'), 1),
#  (('price', 'imtuf', 'picked', 'pair', 'size'), 1),
#  (('imtuf', 'picked', 'pair', 'size', '10 5'), 1),
#  (('picked', 'pair', 'size', '10 5', 'foot'), 1),
#  (('pair', 'size', '10 5', 'foot', 'issues'), 1),
#  (('size', '10 5', 'foot', 'issues', 'felt'), 1),
#  (('10 5', 'foot', 'issues', 'felt', 'bit'), 1),
#  (('foot', 'issues', 'felt', 'bit', 'loose'), 1),
#  (('issues', 'felt', 'bit', 'loose', 'beginning'), 1),
#  (('felt', 'bit', 'loose', 'beginning', 'laced'), 1),
#  (('bit', 'loose', 'beginning', 'laced', 'bit'), 1),
#  (('loose', 'beginning', 'laced', 'bit', 'tighter'), 1),
#  (('beginning', 'laced', 'bit', 'tighter', 'feet'), 1),
#  (('laced', 'bit', 'tighter', 'feet', 'swelled'), 1),
#  (('bit', 'tighter', 'feet', 'swelled', 'race'), 1),
#  (('tighter', 'feet', 'swelled', 'race', 'fit'), 1),
#  (('feet', 'swelled', 'race', 'fit', 'improved'), 1),
#  (('swelled', 'race', 'fit', 'improved', 'felt'), 1),
#  (('race', 'fit', 'improved', 'felt', 'great'), 1),
#  (('fit', 'improved', 'felt', 'great', '2nd'), 1),
#  (('improved', 'felt', 'great', '2nd', 'half'), 1),
#  (('felt', 'great', '2nd', 'half', 'race'), 1),
#  (('great', '2nd', 'half', 'race', 'recommend'), 1),
#  (('2nd', 'half', 'race', 'recommend', '½'), 1),
#  (('half', 'race', 'recommend', '½', 'size'), 1),
#  (('race', 'recommend', '½', 'size', 'intend'), 1),
#  (('recommend', '½', 'size', 'intend', 'scenario'), 1),
#  (('½', 'size', 'intend', 'scenario', 'foot'), 1),
#  (('size', 'intend', 'scenario', 'foot', 'swelling'), 1),
#  (('intend', 'scenario', 'foot', 'swelling', 'play midsolesam'), 1),
#  (('scenario', 'foot', 'swelling', 'play midsolesam', 'midsole'), 1),
#  (('foot', 'swelling', 'play midsolesam', 'midsole', 'features'), 1),
#  (('swelling', 'play midsolesam', 'midsole', 'features', 'bottom'), 1),
#  (('play midsolesam', 'midsole', 'features', 'bottom', 'layer'), 1),
#  (('midsole', 'features', 'bottom', 'layer', 'hoka'), 1),
#  (('features', 'bottom', 'layer', 'hoka', 'responsive'), 1),
#  (('bottom', 'layer', 'hoka', 'responsive', 'supercritical'), 1),
#  (('layer', 'hoka', 'responsive', 'supercritical', 'cmeva'), 1),
#  (('hoka', 'responsive', 'supercritical', 'cmeva', 'foam'), 1),
#  (('responsive', 'supercritical', 'cmeva', 'foam', 'slightly'), 1),
#  (('supercritical', 'cmeva', 'foam', 'slightly', 'softer'), 1),
#  (('cmeva', 'foam', 'slightly', 'softer', 'bouncier'), 1),
#  (('foam', 'slightly', 'softer', 'bouncier', 'layer'), 1),
#  (('slightly', 'softer', 'bouncier', 'layer', 'foam'), 1),
#  (('softer', 'bouncier', 'layer', 'foam', 'construction'), 1),
#  (('bouncier', 'layer', 'foam', 'construction', 'hoka'), 1),
#  (('layer', 'foam', 'construction', 'hoka', 'calls'), 1),
#  (('foam', 'construction', 'hoka', 'calls', 'profly'), 1),
#  (('construction', 'hoka', 'calls', 'profly', 'weight'), 1),
#  (('hoka', 'calls', 'profly', 'weight', 'cushion'), 1),
#  (('calls', 'profly', 'weight', 'cushion', 'ratio'), 1),
#  (('profly', 'weight', 'cushion', 'ratio', 'outstanding'), 1),
#  (('weight', 'cushion', 'ratio', 'outstanding', '8 9'), 1),
#  (('cushion', 'ratio', 'outstanding', '8 9', 'oz'), 1),
#  (('ratio', 'outstanding', '8 9', 'oz', '252'), 1),
#  (('outstanding', '8 9', 'oz', '252', 'shoe'), 1),
#  (('8 9', 'oz', '252', 'shoe', 'big'), 1),
#  (('oz', '252', 'shoe', 'big', '33 29'), 1),
#  (('252', 'shoe', 'big', '33 29', 'stack'), 1),
#  (('shoe', 'big', '33 29', 'stack', 'height'), 1),
#  (('big', '33 29', 'stack', 'height', 'lighter'), 1),
#  (('33 29', 'stack', 'height', 'lighter', 'speedgoat'), 1),
#  (('stack', 'height', 'lighter', 'speedgoat', '5'), 1),
#  (('height', 'lighter', 'speedgoat', '5', 'shoe'), 1),
#  (('lighter', 'speedgoat', '5', 'shoe', 'weighs'), 1),
#  (('speedgoat', '5', 'shoe', 'weighs', '0 85'), 1),
#  (('5', 'shoe', 'weighs', '0 85', 'oz'), 1),
#  (('shoe', 'weighs', '0 85', 'oz', '24g'), 1),
#  (('weighs', '0 85', 'oz', '24g', 'speedgoat'), 1),
#  (('0 85', 'oz', '24g', 'speedgoat', 'ah'), 1),
#  (('oz', '24g', 'speedgoat', 'ah', 'advantages'), 1),
#  (('24g', 'speedgoat', 'ah', 'advantages', 'weight'), 1),
#  (('speedgoat', 'ah', 'advantages', 'weight', 'ride'), 1),
#  (('ah', 'advantages', 'weight', 'ride', 'supercritical'), 1),
#  (('advantages', 'weight', 'ride', 'supercritical', 'foam'), 1),
#  (('weight', 'ride', 'supercritical', 'foam', 'midsole'), 1),
#  (('ride', 'supercritical', 'foam', 'midsole', 'highly'), 1),
#  (('supercritical', 'foam', 'midsole', 'highly', 'protective'), 1),
#  (('foam', 'midsole', 'highly', 'protective', 'responsive'), 1),
#  (('midsole', 'highly', 'protective', 'responsive', 'softer'), 1),
#  (('highly', 'protective', 'responsive', 'softer', 'landing'), 1),
#  (('protective', 'responsive', 'softer', 'landing', 'springy'), 1),
#  (('responsive', 'softer', 'landing', 'springy', 'dense'), 1),
#  (('softer', 'landing', 'springy', 'dense', 'rebound'), 1),
#  (('landing', 'springy', 'dense', 'rebound', 'lower'), 1),
#  (('springy', 'dense', 'rebound', 'lower', 'supercritical'), 1),
#  (('dense', 'rebound', 'lower', 'supercritical', 'foam'), 1),
#  (('rebound', 'lower', 'supercritical', 'foam', 'reminding'), 1),
#  (('lower', 'supercritical', 'foam', 'reminding', 'skechers'), 1),
#  (('supercritical', 'foam', 'reminding', 'skechers', 'hyperburst'), 1),
#  (('foam', 'reminding', 'skechers', 'hyperburst', 'lower'), 1),
#  (('reminding', 'skechers', 'hyperburst', 'lower', 'layer'), 1),
#  (('skechers', 'hyperburst', 'lower', 'layer', 'springy'), 1),
#  (('hyperburst', 'lower', 'layer', 'springy', 'impulse'), 1),
#  (('lower', 'layer', 'springy', 'impulse', 'toe'), 1),
#  (('layer', 'springy', 'impulse', 'toe', 'carbon'), 1),
#  (('springy', 'impulse', 'toe', 'carbon', 'plates embedded'), 1),
#  (('impulse', 'toe', 'carbon', 'plates embedded', 'midsole'), 1),
#  (('toe', 'carbon', 'plates embedded', 'midsole', 'dual'), 1),
#  (('carbon', 'plates embedded', 'midsole', 'dual', 'parallel'), 1),
#  (('plates embedded', 'midsole', 'dual', 'parallel', 'carbon'), 1),
#  (('midsole', 'dual', 'parallel', 'carbon', 'plates'), 1),
#  (('dual', 'parallel', 'carbon', 'plates', 'unlike'), 1),
#  (('parallel', 'carbon', 'plates', 'unlike', 'conventional'), 1),
#  (('carbon', 'plates', 'unlike', 'conventional', 'carbon'), 1),
#  (('plates', 'unlike', 'conventional', 'carbon', 'road'), 1),
#  (('unlike', 'conventional', 'carbon', 'road', 'race'), 1),
#  (('conventional', 'carbon', 'road', 'race', 'shoe'), 1),
#  (('carbon', 'road', 'race', 'shoe', 'plates'), 1),
#  (('road', 'race', 'shoe', 'plates', 'tecton'), 1),
#  (('race', 'shoe', 'plates', 'tecton', 'moderate'), 1),
#  (('shoe', 'plates', 'tecton', 'moderate', 'longitudinal'), 1),
#  (('plates', 'tecton', 'moderate', 'longitudinal', 'lateral'), 1),
#  (('tecton', 'moderate', 'longitudinal', 'lateral', 'flex'), 1),
#  (('moderate', 'longitudinal', 'lateral', 'flex', 'contouring'), 1),
#  (('longitudinal', 'lateral', 'flex', 'contouring', 'trail'), 1),
#  (('lateral', 'flex', 'contouring', 'trail', 'terrain'), 1),
#  (('flex', 'contouring', 'trail', 'terrain', 'climbing'), 1),
#  (('contouring', 'trail', 'terrain', 'climbing', 'plates'), 1),
#  (('trail', 'terrain', 'climbing', 'plates', 'stiff'), 1),
#  (('terrain', 'climbing', 'plates', 'stiff', 'steep'), 1),
#  (('climbing', 'plates', 'stiff', 'steep', 'climbing'), 1),
#  (('plates', 'stiff', 'steep', 'climbing', 'segments'), 1),
#  (('stiff', 'steep', 'climbing', 'segments', 'require'), 1),
#  (('steep', 'climbing', 'segments', 'require', 'bit'), 1),
#  (('climbing', 'segments', 'require', 'bit', 'drive'), 1),
#  (('segments', 'require', 'bit', 'drive', 'plate'), 1),
#  (('require', 'bit', 'drive', 'plate', 'flats'), 1),
#  (('bit', 'drive', 'plate', 'flats', 'easy'), 1),
#  (('drive', 'plate', 'flats', 'easy', 'climbs'), 1),
#  (('plate', 'flats', 'easy', 'climbs', 'provide'), 1),
#  (('flats', 'easy', 'climbs', 'provide', 'lot'), 1),
#  (('easy', 'climbs', 'provide', 'lot', 'springy'), 1),
#  (('climbs', 'provide', 'lot', 'springy', 'impulse'), 1),
#  (('provide', 'lot', 'springy', 'impulse', 'moderate'), 1),
#  (('lot', 'springy', 'impulse', 'moderate', 'smoother'), 1),
#  (('springy', 'impulse', 'moderate', 'smoother', 'trails'), 1),
#  (('impulse', 'moderate', 'smoother', 'trails', 'midsole'), 1),
#  (('moderate', 'smoother', 'trails', 'midsole', 'plates'), 1),
#  (('smoother', 'trails', 'midsole', 'plates', 'shine'), 1),
#  (('trails', 'midsole', 'plates', 'shine', 'forgiving'), 1),
#  (('midsole', 'plates', 'shine', 'forgiving', 'plated'), 1),
#  (('plates', 'shine', 'forgiving', 'plated', 'characteristics'), 1),
#  (('shine', 'forgiving', 'plated', 'characteristics', 'tecton'), 1),
#  (('forgiving', 'plated', 'characteristics', 'tecton', 'joy'), 1),
#  (('plated', 'characteristics', 'tecton', 'joy', 'run'), 1),
#  (('characteristics', 'tecton', 'joy', 'run', 'road'), 1),
#  (('tecton', 'joy', 'run', 'road', 'understanding'), 1),
#  (('joy', 'run', 'road', 'understanding', 'notice'), 1),
#  (('run', 'road', 'understanding', 'notice', 'vibram'), 1),
#  (('road', 'understanding', 'notice', 'vibram', 'outsole'), 1),
#  (('understanding', 'notice', 'vibram', 'outsole', 'replace'), 1),
#  (('notice', 'vibram', 'outsole', 'replace', 'vibram'), 1),
#  (('vibram', 'outsole', 'replace', 'vibram', 'conventional'), 1),
#  (('outsole', 'replace', 'vibram', 'conventional', 'road'), 1),
#  (('replace', 'vibram', 'conventional', 'road', 'outsole'), 1),
#  (('vibram', 'conventional', 'road', 'outsole', 'superb'), 1),
#  (('conventional', 'road', 'outsole', 'superb', 'long'), 1),
#  (('road', 'outsole', 'superb', 'long', 'road'), 1),
#  (('outsole', 'superb', 'long', 'road', 'trainer'), 1),
#  (('superb', 'long', 'road', 'trainer', 'racer'), 1),
#  (('long', 'road', 'trainer', 'racer', 'full'), 1),
#  (('road', 'trainer', 'racer', 'full', 'stack'), 1),
#  (('trainer', 'racer', 'full', 'stack', 'height'), 1),
#  (('racer', 'full', 'stack', 'height', '33 29'), 1),
#  (('full', 'stack', 'height', '33 29', 'carbon'), 1),
#  (('stack', 'height', '33 29', 'carbon', 'plates'), 1),
#  (('height', '33 29', 'carbon', 'plates', 'vibram'), 1),
#  (('33 29', 'carbon', 'plates', 'vibram', 'lite'), 1),
#  (('carbon', 'plates', 'vibram', 'lite', 'base'), 1),
#  (('plates', 'vibram', 'lite', 'base', 'outsole'), 1),
#  (('vibram', 'lite', 'base', 'outsole', 'provide'), 1),
#  (('lite', 'base', 'outsole', 'provide', 'rock'), 1),
#  (('base', 'outsole', 'provide', 'rock', 'protection'), 1),
#  (('outsole', 'provide', 'rock', 'protection', 'ample jeff'), 1),
#  (('provide', 'rock', 'protection', 'ample jeff', 'sam'), 1),
#  (('rock', 'protection', 'ample jeff', 'sam', 'great'), 1),
#  (('protection', 'ample jeff', 'sam', 'great', 'detailed'), 1),
#  (('ample jeff', 'sam', 'great', 'detailed', 'description'), 1),
#  (('sam', 'great', 'detailed', 'description', 'midsole'), 1),
#  (('great', 'detailed', 'description', 'midsole', 'carbon'), 1),
#  (('detailed', 'description', 'midsole', 'carbon', 'plates'), 1),
#  (('description', 'midsole', 'carbon', 'plates', 'performance'), 1),
#  (('midsole', 'carbon', 'plates', 'performance', 'test'), 1),
#  (('carbon', 'plates', 'performance', 'test', 'tecton'), 1),
#  (('plates', 'performance', 'test', 'tecton', 'wide'), 1),
#  (('performance', 'test', 'tecton', 'wide', 'variety'), 1),
#  (('test', 'tecton', 'wide', 'variety', 'terrain'), 1),
#  (('tecton', 'wide', 'variety', 'terrain', 'including'), 1),
#  (('wide', 'variety', 'terrain', 'including', 'dirt'), 1),
#  (('variety', 'terrain', 'including', 'dirt', 'roads'), 1),
#  (('terrain', 'including', 'dirt', 'roads', 'paved'), 1),
#  (('including', 'dirt', 'roads', 'paved', 'roads'), 1),
#  (('dirt', 'roads', 'paved', 'roads', 'buffed'), 1),
#  (('roads', 'paved', 'roads', 'buffed', 'singletrack'), 1),
#  (('paved', 'roads', 'buffed', 'singletrack', 'semi'), 1),
#  (('roads', 'buffed', 'singletrack', 'semi', 'technical'), 1),
#  (('buffed', 'singletrack', 'semi', 'technical', 'singletrack'), 1),
#  (('singletrack', 'semi', 'technical', 'singletrack', 'steep'), 1),
#  (('semi', 'technical', 'singletrack', 'steep', 'technical'), 1),
#  (('technical', 'singletrack', 'steep', 'technical', 'trails'), 1),
#  (('singletrack', 'steep', 'technical', 'trails', 'found'), 1),
#  (('steep', 'technical', 'trails', 'found', 'performance'), 1),
#  (('technical', 'trails', 'found', 'performance', 'vary'), 1),
#  (('trails', 'found', 'performance', 'vary', 'significantly'), 1),
#  (('found', 'performance', 'vary', 'significantly', 'depending'), 1),
#  (('performance', 'vary', 'significantly', 'depending', 'gradient'), 1),
#  (('vary', 'significantly', 'depending', 'gradient', 'trail'), 1),
#  (('significantly', 'depending', 'gradient', 'trail', 'surface'), 1),
#  (('depending', 'gradient', 'trail', 'surface', 'pace'), 1),
#  (('gradient', 'trail', 'surface', 'pace', 'general'), 1),
#  (('trail', 'surface', 'pace', 'general', 'uphills'), 1),
#  (('surface', 'pace', 'general', 'uphills', 'gradient'), 1),
#  (('pace', 'general', 'uphills', 'gradient', 'find'), 1),
#  (('general', 'uphills', 'gradient', 'find', 'carbon'), 1),
#  (('uphills', 'gradient', 'find', 'carbon', 'plates'), 1),
#  (('gradient', 'find', 'carbon', 'plates', 'provide'), 1),
#  (('find', 'carbon', 'plates', 'provide', 'propulsive'), 1),
#  (('carbon', 'plates', 'provide', 'propulsive', 'advantage'), 1),
#  (('plates', 'provide', 'propulsive', 'advantage', 'light'), 1),
#  (('provide', 'propulsive', 'advantage', 'light', 'lively'), 1),
#  (('propulsive', 'advantage', 'light', 'lively', 'responsive'), 1),
#  (('advantage', 'light', 'lively', 'responsive', 'feeling'), 1),
#  (('light', 'lively', 'responsive', 'feeling', 'strong'), 1),
#  (('lively', 'responsive', 'feeling', 'strong', 'lower'), 1),
#  (('responsive', 'feeling', 'strong', 'lower', 'gradient'), 1),
#  (('feeling', 'strong', 'lower', 'gradient', 'uphills'), 1),
#  (('strong', 'lower', 'gradient', 'uphills', 'find'), 1),
#  (('lower', 'gradient', 'uphills', 'find', 'offer'), 1),
#  (('gradient', 'uphills', 'find', 'offer', 'pop'), 1),
#  (('uphills', 'find', 'offer', 'pop', 'pushed'), 1),
#  (('find', 'offer', 'pop', 'pushed', 'steeper'), 1),
#  (('offer', 'pop', 'pushed', 'steeper', 'technical'), 1),
#  (('pop', 'pushed', 'steeper', 'technical', 'terrain'), 1),
#  (('pushed', 'steeper', 'technical', 'terrain', 'detect'), 1),
#  (('steeper', 'technical', 'terrain', 'detect', 'advantage'), 1),
#  (('technical', 'terrain', 'detect', 'advantage', 'running'), 1),
#  (('terrain', 'detect', 'advantage', 'running', 'flats'), 1),
#  (('detect', 'advantage', 'running', 'flats', 'low'), 1),
#  (('advantage', 'running', 'flats', 'low', 'gradients'), 1),
#  (('running', 'flats', 'low', 'gradients', 'technical'), 1),
#  (('flats', 'low', 'gradients', 'technical', 'downhills'), 1),
#  (('low', 'gradients', 'technical', 'downhills', 'plate'), 1),
#  (('gradients', 'technical', 'downhills', 'plate', 'working'), 1),
#  (('technical', 'downhills', 'plate', 'working', 'generate'), 1),
#  (('downhills', 'plate', 'working', 'generate', 'energy'), 1),
#  (('plate', 'working', 'generate', 'energy', 'moving'), 1),
#  (('working', 'generate', 'energy', 'moving', 'faster'), 1),
#  (('generate', 'energy', 'moving', 'faster', 'speeds'), 1),
#  (('energy', 'moving', 'faster', 'speeds', 'opened'), 1),
#  (('moving', 'faster', 'speeds', 'opened', 'stride'), 1),
#  (('faster', 'speeds', 'opened', 'stride', 'find'), 1),
#  (('speeds', 'opened', 'stride', 'find', 'protection'), 1),
#  (('opened', 'stride', 'find', 'protection', 'good'), 1),
#  (('stride', 'find', 'protection', 'good', 'carbon'), 1),
#  (('find', 'protection', 'good', 'carbon', 'plates'), 1),
#  (('protection', 'good', 'carbon', 'plates', 'flexing'), 1),
#  (('good', 'carbon', 'plates', 'flexing', 'varied'), 1),
#  (('carbon', 'plates', 'flexing', 'varied', 'terrain'), 1),
#  (('plates', 'flexing', 'varied', 'terrain', 'feels'), 1),
#  (('flexing', 'varied', 'terrain', 'feels', 'bit'), 1),
#  (('varied', 'terrain', 'feels', 'bit', 'stiff'), 1),
#  (('terrain', 'feels', 'bit', 'stiff', 'rigid'), 1),
#  (('feels', 'bit', 'stiff', 'rigid', 'north'), 1),
#  (('bit', 'stiff', 'rigid', 'north', 'face'), 1),
#  (('stiff', 'rigid', 'north', 'face', 'flight'), 1),
#  (('rigid', 'north', 'face', 'flight', 'vectiv'), 1),
#  (('north', 'face', 'flight', 'vectiv', 'vimana'), 1),
#  (('face', 'flight', 'vectiv', 'vimana', 'carbon'), 1),
#  (('flight', 'vectiv', 'vimana', 'carbon', 'runner'), 1),
#  (('vectiv', 'vimana', 'carbon', 'runner', 'compliant'), 1),
#  (('vimana', 'carbon', 'runner', 'compliant', 'flexible'), 1),
#  (('carbon', 'runner', 'compliant', 'flexible', 'speedland'), 1),
#  (('runner', 'compliant', 'flexible', 'speedland', 'sl'), 1),
#  (('compliant', 'flexible', 'speedland', 'sl', 'pdx'), 1),
#  (('flexible', 'speedland', 'sl', 'pdx', 'flexible'), 1),
#  (('speedland', 'sl', 'pdx', 'flexible', 'carbitex'), 1),
#  (('sl', 'pdx', 'flexible', 'carbitex', 'plate'), 1),
#  (('pdx', 'flexible', 'carbitex', 'plate', 'cushioning'), 1),
#  (('flexible', 'carbitex', 'plate', 'cushioning', 'adequate'), 1),
#  (('carbitex', 'plate', 'cushioning', 'adequate', 'found'), 1),
#  (('plate', 'cushioning', 'adequate', 'found', 'firm'), 1),
#  (('cushioning', 'adequate', 'found', 'firm', 'side'), 1),
#  (('adequate', 'found', 'firm', 'side', 'noticed'), 1),
#  ...]
